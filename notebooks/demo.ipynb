# %% [markdown]
# # SMC-Learning Boat Demo
# Student: 謝濬遠 (114024511)
#
# This notebook runs a short version of the reproducible demo. For the complete CLI experiment, use `scripts/run_demo.py`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from src.training import TrainConfig, train_smc, evaluate_policy
from src.plotting import plot_trajectories

# %%
cfg = TrainConfig(episodes=1000, state_bins=6)
result, agent = train_smc(114024511, 10, cfg)
print('mean final 100 reward:', result.rewards[-100:].mean())
evaluation = evaluate_policy(agent, 'smc', cfg, episodes=20)
evaluation = {k:v for k,v in evaluation.items() if k != 'trajectories'}
evaluation
